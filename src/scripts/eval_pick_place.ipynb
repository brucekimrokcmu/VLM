# %%
import os
from os.path import join, dirname, abspath
import sys
CURRENT_DIR = os.getcwd()
sys.path.insert(0, join(CURRENT_DIR, '../..'))  # Import local models

from cliport.environments.environment import Environment
import torch
from models.PickModel import PickModel
from models.PlaceModel import PlaceModel
from agents.PickPlaceAgent import PickPlaceAgent
from cliport import tasks
from cliport.dataset import RavensDataset
import numpy as np
from cliport.utils import utils

# %%
record_cfg = {
  "save_video": False,
  "save_video_path": "/home/ubuntu/VLM/videos/",
  "add_text": True,
  "fps": 20,
  "video_height": 640,
  "video_width": 720,
}

assets_root = "/home/ubuntu/cliport/cliport/environments/assets/"

env = Environment(
    assets_root,
    disp=False,
    shared_memory=False,
    hz=480,
    record_cfg=record_cfg
)

# %%
agent = PickPlaceAgent(num_rotations=12, lr=1e-4, device='cuda')

# %%
agent.pick_model.load_state_dict(torch.load("/home/ubuntu/VLM/checkpoints/checkpoint_PairPack_latest.pth")['pick_state_dict'])
agent.place_model.load_state_dict(torch.load("/home/ubuntu/VLM/checkpoints/checkpoint_PairPack_latest.pth")['place_state_dict'])
# Out:
# <All keys matched successfully>

# %%
train_dataset_cfg = {"dataset":{"type": "single",
                    "images": True,
                    "cache": False,
                    "augment":{"theta_sigma":60},
                    "cache_size": 350},
                    }

# load data
train_dataset = RavensDataset('/home/ubuntu/cliport/data/packing-boxes-pairs-full-val', train_dataset_cfg, n_demos=100, augment=False)

# %%
total_reward = 0
num_trials = 100
for i in range(num_trials):
    env.start_rec("pick-place-pairs" + str(i))

    episode, seed = train_dataset.load(i)
    task = tasks.names["packing-boxes-pairs-full"]()
    task.mode = "train"
    env.seed(seed)
    env.set_task(task)
    obs = env.reset()
    info = env.info
    episode_reward = 0

    lang_goal = info['lang_goal']
    print(f'Lang Goal: {lang_goal}')
    
    for _ in range(10):
        img = train_dataset.get_image(obs)
        lang_goal = info['lang_goal']
        act, affordances = agent.act(img, lang_goal)

        obs, reward, done, info = env.step(act)
        episode_reward += reward
        total_reward += reward
        print("Single timestep reward:", reward)
        if done:
            break
    print("Iteration:", i)
    print("Episode Reward:", episode_reward)
    print("Average Reward Across Episodes:", total_reward/(i+1))
    env.end_rec()
# Out:
# Lang Goal: pack all the gray and pink blocks into the brown box
# Single timestep reward: 0.05625
# Single timestep reward: 0.05625
# Single timestep reward: 0.05625000000000001
# Single timestep reward: 0.11041666666666666
# Single timestep reward: 0.0
# Single timestep reward: 0.07500000000000001
# Single timestep reward: 0.11041666666666666
# Single timestep reward: 0.09583333333333333
# Single timestep reward: 0.07916666666666661
# Single timestep reward: 0.09791666666666676
# Iteration: 0
# Episode Reward: 0.7375
# Average Reward Across Episodes: 0.7375
# Lang Goal: pack all the purple and cyan blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.25
# Single timestep reward: 0.25
# Single timestep reward: 0.0
# Single timestep reward: 0.16666666666666663
# Single timestep reward: 0.25
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 1
# Episode Reward: 0.9166666666666666
# Average Reward Across Episodes: 0.8270833333333334
# Lang Goal: pack all the brown and green blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.3
# Single timestep reward: 0.0
# Single timestep reward: 0.1777777777777778
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.13333333333333336
# Single timestep reward: 0.0444444444444444
# Iteration: 2
# Episode Reward: 0.6555555555555556
# Average Reward Across Episodes: 0.7699074074074074
# Lang Goal: pack all the orange blocks into the brown box
# Single timestep reward: 1.0
# Iteration: 3
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.8274305555555556
# Lang Goal: pack all the brown and white blocks into the brown box
# Single timestep reward: 0.375
# Single timestep reward: 0.25
# Single timestep reward: 0.0
# Single timestep reward: -0.25
# Single timestep reward: 0.38888888888888884
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.11111111111111116
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 4
# Episode Reward: 0.875
# Average Reward Across Episodes: 0.8369444444444444
# Lang Goal: pack all the green and white blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.03636363636363636
# Single timestep reward: 0.08181818181818182
# Single timestep reward: 0.10909090909090909
# Single timestep reward: 0.13636363636363638
# Single timestep reward: 0.0
# Single timestep reward: 0.06666666666666665
# Single timestep reward: 0.033333333333333326
# Single timestep reward: 0.09090909090909094
# Single timestep reward: 0.06060606060606055
# Iteration: 5
# Episode Reward: 0.6151515151515151
# Average Reward Across Episodes: 0.7999789562289562
# Lang Goal: pack all the orange and red blocks into the brown box
# Single timestep reward: 0.19736842105263158
# Single timestep reward: 0.13596491228070173
# Single timestep reward: 0.09649122807017546
# Single timestep reward: 0.2192982456140351
# Single timestep reward: -0.13596491228070173
# Single timestep reward: 0.10526315789473684
# Single timestep reward: -0.10087719298245612
# Single timestep reward: 0.06140350877192979
# Single timestep reward: 0.05701754385964908
# Single timestep reward: 0.08771929824561409
# Iteration: 6
# Episode Reward: 0.7236842105263158
# Average Reward Across Episodes: 0.7890797068428647
# Lang Goal: pack all the white and blue blocks into the brown box
# Single timestep reward: 0.36363636363636365
# Single timestep reward: 0.16161616161616166
# Single timestep reward: 0.06060606060606055
# Single timestep reward: 0.18181818181818177
# Single timestep reward: -0.13131313131313127
# Single timestep reward: 0.202020202020202
# Single timestep reward: -0.202020202020202
# Single timestep reward: 0.0
# Single timestep reward: 0.07070707070707072
# Single timestep reward: -0.07070707070707072
# Iteration: 7
# Episode Reward: 0.6363636363636364
# Average Reward Across Episodes: 0.7699901980329611
# Lang Goal: pack all the pink and purple blocks into the brown box
# Single timestep reward: 0.42857142857142855
# Single timestep reward: 0.45714285714285713
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.45714285714285713
# Single timestep reward: 0.0
# Single timestep reward: 0.14285714285714285
# Iteration: 8
# Episode Reward: 0.5714285714285714
# Average Reward Across Episodes: 0.7479277950769179
# Lang Goal: pack all the cyan and gray blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.42857142857142855
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.14285714285714285
# Single timestep reward: -0.14285714285714285
# Single timestep reward: 0.0
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.0
# Iteration: 9
# Episode Reward: 0.5714285714285714
# Average Reward Across Episodes: 0.7302778727120833
# Lang Goal: pack all the cyan and purple blocks into the brown box
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.0
# Single timestep reward: 0.2857142857142857
# Single timestep reward: 0.047619047619047616
# Single timestep reward: 0.0
# Single timestep reward: -0.047619047619047616
# Single timestep reward: 0.0
# Single timestep reward: 0.23809523809523808
# Single timestep reward: 0.0
# Single timestep reward: -0.23809523809523808
# Iteration: 10
# Episode Reward: 0.42857142857142855
# Average Reward Across Episodes: 0.702850014153842
# Lang Goal: pack all the yellow and brown blocks into the brown box
# Single timestep reward: 0.21428571428571427
# Single timestep reward: 0.21428571428571427
# Single timestep reward: 0.0
# Single timestep reward: 0.16071428571428575
# Single timestep reward: -0.08333333333333337
# Single timestep reward: 0.13690476190476197
# Single timestep reward: 0.23809523809523803
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 11
# Episode Reward: 0.8809523809523809
# Average Reward Across Episodes: 0.7176918780537203
# Lang Goal: pack all the gray and orange blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.4305555555555556
# Single timestep reward: 0.06944444444444442
# Single timestep reward: 0.11111111111111116
# Single timestep reward: 0.0
# Single timestep reward: 0.18055555555555547
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.29166666666666663
# Single timestep reward: 0.5
# Iteration: 12
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.7394078874342033
# Lang Goal: pack all the white and pink blocks into the brown box
# Single timestep reward: 0.19444444444444445
# Single timestep reward: 0.0
# Single timestep reward: 0.24999999999999997
# Single timestep reward: 0.2222222222222222
# Single timestep reward: 0.006944444444444531
# Single timestep reward: 0.03472222222222221
# Single timestep reward: 0.0
# Single timestep reward: -0.03472222222222221
# Single timestep reward: 0.02777777777777768
# Single timestep reward: 0.01388888888888895
# Iteration: 13
# Episode Reward: 0.7152777777777778
# Average Reward Across Episodes: 0.73768430817303
# Lang Goal: pack all the purple and yellow blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 14
# Episode Reward: 0.0
# Average Reward Across Episodes: 0.688505354294828
# Lang Goal: pack all the pink and yellow blocks into the brown box
# Single timestep reward: 0.2727272727272727
# Single timestep reward: 0.24242424242424243
# Single timestep reward: 0.2727272727272727
# Single timestep reward: 0.0
# Single timestep reward: -0.24242424242424243
# Single timestep reward: 0.36363636363636365
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 15
# Episode Reward: 0.9090909090909091
# Average Reward Across Episodes: 0.7022919514695831
# Lang Goal: pack all the gray and white blocks into the brown box
# Single timestep reward: 0.31746031746031744
# Single timestep reward: 0.19047619047619047
# Single timestep reward: 0.09523809523809523
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.010582010582010581
# Single timestep reward: -0.08465608465608465
# Single timestep reward: 0.042328042328042326
# Single timestep reward: 0.06349206349206349
# Single timestep reward: -0.08465608465608465
# Iteration: 16
# Episode Reward: 0.5502645502645502
# Average Reward Across Episodes: 0.6933491631634048
# Lang Goal: pack all the blue and brown blocks into the brown box
# Single timestep reward: 0.1079136690647482
# Single timestep reward: 0.08633093525179858
# Single timestep reward: 0.0767386091127098
# Single timestep reward: -0.0767386091127098
# Single timestep reward: 0.08153477218225419
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0959232613908873
# Single timestep reward: 0.0767386091127098
# Iteration: 17
# Episode Reward: 0.44844124700239807
# Average Reward Across Episodes: 0.6797431678211265
# Lang Goal: pack all the orange and cyan blocks into the brown box
# Single timestep reward: 0.14814814814814814
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.1111111111111111
# Single timestep reward: -0.25925925925925924
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.5
# Single timestep reward: 0.07407407407407407
# Single timestep reward: -0.05555555555555558
# Iteration: 18
# Episode Reward: 0.5185185185185185
# Average Reward Across Episodes: 0.6712576599630945
# Lang Goal: pack all the purple and brown blocks into the brown box
# Single timestep reward: 0.16
# Single timestep reward: 0.12000000000000002
# Single timestep reward: 0.12
# Single timestep reward: 0.12
# Single timestep reward: 0.12
# Single timestep reward: 0.0
# Single timestep reward: 0.07111111111111112
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 19
# Episode Reward: 0.7111111111111111
# Average Reward Across Episodes: 0.6732503325204953
# Lang Goal: pack all the blue and orange blocks into the brown box
# Single timestep reward: 0.16666666666666666
# Single timestep reward: 0.16666666666666666
# Single timestep reward: 0.1111111111111111
# Single timestep reward: 0.12345679012345678
# Single timestep reward: 0.16666666666666674
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 20
# Episode Reward: 0.7345679012345679
# Average Reward Across Episodes: 0.6761702167449748
# Lang Goal: pack all the gray and purple blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.5
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 21
# Episode Reward: 0.5
# Average Reward Across Episodes: 0.6681624796202033
# Lang Goal: pack all the gray and red blocks into the brown box
# Single timestep reward: 0.3
# Single timestep reward: 0.3
# Single timestep reward: 0.2666666666666667
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.022222222222222254
# Single timestep reward: 0.0
# Single timestep reward: -0.1444444444444445
# Single timestep reward: 0.0
# Iteration: 22
# Episode Reward: 0.7
# Average Reward Across Episodes: 0.6695467196367162
# Lang Goal: pack all the pink and orange blocks into the brown box
# Single timestep reward: 0.10714285714285714
# Single timestep reward: 0.10714285714285714
# Single timestep reward: 0.09523809523809526
# Single timestep reward: 0.0
# Single timestep reward: 0.10714285714285715
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.10714285714285715
# Single timestep reward: 0.0714285714285714
# Single timestep reward: 0.04365079365079361
# Iteration: 23
# Episode Reward: 0.6388888888888888
# Average Reward Across Episodes: 0.6682693100222235
# Lang Goal: pack all the orange blocks into the brown box
# Single timestep reward: 0.4
# Single timestep reward: -0.4
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.5833333333333334
# Single timestep reward: 0.1499999999999999
# Single timestep reward: 0.2666666666666667
# Iteration: 24
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.6815385376213343
# Lang Goal: pack all the purple and orange blocks into the brown box
# Single timestep reward: 0.17094017094017094
# Single timestep reward: 0.0
# Single timestep reward: 0.2393162393162393
# Single timestep reward: 0.06837606837606841
# Single timestep reward: 0.17948717948717946
# Single timestep reward: -0.008547008547008517
# Single timestep reward: 0.008547008547008517
# Single timestep reward: 0.017094017094017144
# Single timestep reward: 0.0
# Single timestep reward: 0.05128205128205121
# Iteration: 25
# Episode Reward: 0.7264957264957265
# Average Reward Across Episodes: 0.6832676602703494
# Lang Goal: pack all the green and gray blocks into the brown box
# Single timestep reward: 0.17582417582417584
# Single timestep reward: 0.13186813186813187
# Single timestep reward: 0.07692307692307693
# Single timestep reward: 0.1318681318681319
# Single timestep reward: 0.02564102564102555
# Single timestep reward: 0.08424908424908428
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.11721611721611724
# Iteration: 26
# Episode Reward: 0.7435897435897436
# Average Reward Across Episodes: 0.6855018115044009
# Lang Goal: pack all the yellow and blue blocks into the brown box
# Single timestep reward: 0.2191780821917808
# Single timestep reward: 0.1232876712328767
# Single timestep reward: 0.0
# Single timestep reward: 0.0821917808219178
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.13698630136986306
# Single timestep reward: 0.0
# Iteration: 27
# Episode Reward: 0.5616438356164384
# Average Reward Across Episodes: 0.6810783123655452
# Lang Goal: pack all the yellow and blue blocks into the brown box
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.16363636363636364
# Single timestep reward: 0.036363636363636376
# Single timestep reward: -0.036363636363636376
# Single timestep reward: 0.006060606060606044
# Single timestep reward: 0.0
# Single timestep reward: 0.018181818181818188
# Single timestep reward: 0.054545454545454564
# Iteration: 28
# Episode Reward: 0.36363636363636365
# Average Reward Across Episodes: 0.6701320382714355
# Lang Goal: pack all the red and purple blocks into the brown box
# Single timestep reward: 0.11666666666666667
# Single timestep reward: 0.5833333333333333
# Single timestep reward: 0.08333333333333337
# Single timestep reward: 0.16666666666666663
# Single timestep reward: -0.25
# Single timestep reward: 0.0
# Single timestep reward: 0.30000000000000004
# Iteration: 29
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.681127636995721
# Lang Goal: pack all the gray and brown blocks into the brown box
# Single timestep reward: 0.125
# Single timestep reward: 0.16666666666666669
# Single timestep reward: -0.2916666666666667
# Single timestep reward: 0.08333333333333333
# Single timestep reward: 0.5
# Single timestep reward: -0.08333333333333337
# Single timestep reward: 0.125
# Single timestep reward: 0.0
# Warning: movej exceeded 5 second timeout. Skipping.
# Single timestep reward: 0.0
# Iteration: 30
# Episode Reward: 0.625
# Average Reward Across Episodes: 0.6793170680603752
# Lang Goal: pack all the brown and orange blocks into the brown box
# Single timestep reward: 0.10843373493975904
# Single timestep reward: 0.18072289156626503
# Single timestep reward: 0.14457831325301207
# Single timestep reward: 0.04819277108433734
# Single timestep reward: 0.09638554216867468
# Single timestep reward: 0.1325301204819277
# Single timestep reward: 0.004016064257028162
# Single timestep reward: 0.0
# Single timestep reward: -0.23694779116465864
# Single timestep reward: 0.18072289156626503
# Iteration: 31
# Episode Reward: 0.6586345381526104
# Average Reward Across Episodes: 0.6786707390007575
# Lang Goal: pack all the red and cyan blocks into the brown box
# Single timestep reward: 0.1111111111111111
# Single timestep reward: 0.16049382716049382
# Single timestep reward: 0.14197530864197533
# Single timestep reward: 0.12345679012345684
# Single timestep reward: 0.17901234567901225
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.01851851851851849
# Single timestep reward: -0.012345679012345623
# Iteration: 32
# Episode Reward: 0.6851851851851852
# Average Reward Across Episodes: 0.6788681464608916
# Lang Goal: pack all the purple and white blocks into the brown box
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.0
# Single timestep reward: 0.13468013468013468
# Single timestep reward: 0.0
# Single timestep reward: 0.06060606060606061
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.06060606060606061
# Iteration: 33
# Episode Reward: 0.4983164983164983
# Average Reward Across Episodes: 0.6735578038684096
# Lang Goal: pack all the purple and pink blocks into the brown box
# Single timestep reward: 0.11538461538461539
# Single timestep reward: 0.08653846153846154
# Single timestep reward: 0.08653846153846151
# Single timestep reward: 0.14423076923076927
# Single timestep reward: 0.07692307692307687
# Single timestep reward: 0.09615384615384615
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.14423076923076916
# Single timestep reward: 0.038461538461538436
# Iteration: 34
# Episode Reward: 0.5
# Average Reward Across Episodes: 0.6685990094721692
# Lang Goal: pack all the blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 35
# Episode Reward: 0.0
# Average Reward Across Episodes: 0.650026814764609
# Lang Goal: pack all the pink and brown blocks into the brown box
# Single timestep reward: 0.10714285714285714
# Single timestep reward: 0.17857142857142855
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.09821428571428575
# Single timestep reward: 0.1160714285714286
# Single timestep reward: 0.0
# Single timestep reward: 0.09523809523809523
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 36
# Episode Reward: 0.7380952380952381
# Average Reward Across Episodes: 0.6524070424221935
# Lang Goal: pack all the blue and white blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.11538461538461539
# Single timestep reward: 0.11538461538461539
# Single timestep reward: 0.11538461538461536
# Single timestep reward: 0.10256410256410259
# Single timestep reward: 0.1538461538461538
# Single timestep reward: 0.09615384615384615
# Single timestep reward: 0.0032051282051281937
# Single timestep reward: 0.054487179487179516
# Single timestep reward: 0.0641025641025641
# Iteration: 37
# Episode Reward: 0.8205128205128205
# Average Reward Across Episodes: 0.6568308786877364
# Lang Goal: pack all the red and white blocks into the brown box
# Single timestep reward: 0.10714285714285714
# Single timestep reward: 0.1011904761904762
# Single timestep reward: 0.13988095238095236
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.0
# Single timestep reward: 0.04464285714285715
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 38
# Episode Reward: 0.5357142857142857
# Average Reward Across Episodes: 0.6537253250217504
# Lang Goal: pack all the green and yellow blocks into the brown box
# Single timestep reward: 0.08633093525179857
# Single timestep reward: 0.08393285371702637
# Single timestep reward: 0.07434052757793766
# Single timestep reward: 0.11750599520383695
# Single timestep reward: 0.1151079136690647
# Single timestep reward: 0.04556354916067146
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.043165467625899234
# Single timestep reward: 0.04796163069544368
# Iteration: 39
# Episode Reward: 0.5275779376498801
# Average Reward Across Episodes: 0.6505716403374536
# Lang Goal: pack all the gray and green blocks into the brown box
# Single timestep reward: 0.07317073170731707
# Single timestep reward: 0.11111111111111112
# Single timestep reward: 0.11653116531165314
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.08130081300813008
# Single timestep reward: 0.0
# Single timestep reward: 0.09756097560975607
# Single timestep reward: 0.06775067750677505
# Single timestep reward: 0.08943089430894313
# Iteration: 40
# Episode Reward: 0.6368563685636857
# Average Reward Across Episodes: 0.6502371215137033
# Lang Goal: pack all the cyan and red blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.09876543209876543
# Single timestep reward: 0.2222222222222222
# Single timestep reward: 0.08641975308641975
# Single timestep reward: 0.09259259259259262
# Single timestep reward: 0.11111111111111116
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.012345679012345734
# Single timestep reward: 0.030864197530864224
# Iteration: 41
# Episode Reward: 0.6296296296296297
# Average Reward Across Episodes: 0.6497464669450348
# Lang Goal: pack all the pink and gray blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.18666666666666668
# Single timestep reward: 0.013333333333333336
# Single timestep reward: 0.033333333333333326
# Single timestep reward: 0.11333333333333334
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.006666666666666654
# Single timestep reward: -0.34
# Iteration: 42
# Episode Reward: 0.0
# Average Reward Across Episodes: 0.6346360839928247
# Lang Goal: pack all the green and red blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.5
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.3055555555555556
# Single timestep reward: 0.19444444444444442
# Iteration: 43
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.6429398093566241
# Lang Goal: pack all the cyan and pink blocks into the brown box
# Single timestep reward: 0.06
# Single timestep reward: 0.06
# Single timestep reward: 0.0
# Single timestep reward: 0.06
# Single timestep reward: 0.06
# Single timestep reward: 0.06
# Single timestep reward: 0.0
# Single timestep reward: 0.053333333333333344
# Single timestep reward: 0.033333333333333326
# Single timestep reward: 0.06666666666666665
# Iteration: 44
# Episode Reward: 0.4533333333333333
# Average Reward Across Episodes: 0.6387263321116621
# Lang Goal: pack all the yellow and red blocks into the brown box
# Single timestep reward: 0.17142857142857143
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.17142857142857143
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.04285714285714287
# Single timestep reward: 0.023809523809523836
# Single timestep reward: -0.004761904761904745
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 45
# Episode Reward: 0.5476190476190477
# Average Reward Across Episodes: 0.6367457389705183
# Lang Goal: pack all the blue and white blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.20370370370370372
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0092592592592593
# Iteration: 46
# Episode Reward: 0.8796296296296297
# Average Reward Across Episodes: 0.6419134813249674
# Lang Goal: pack all the red blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.06666666666666667
# Single timestep reward: 0.0
# Iteration: 47
# Episode Reward: 0.06666666666666667
# Average Reward Across Episodes: 0.6299291726862528
# Lang Goal: pack all the purple and blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.36363636363636365
# Single timestep reward: 0.36363636363636365
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.08484848484848484
# Single timestep reward: 0.0
# Single timestep reward: 0.048484848484848464
# Iteration: 48
# Episode Reward: 0.8606060606060606
# Average Reward Across Episodes: 0.6346368642764529
# Lang Goal: pack all the yellow and pink blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.5
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.5
# Single timestep reward: 0.0
# Single timestep reward: 0.3333333333333333
# Single timestep reward: -0.3333333333333333
# Single timestep reward: 0.24074074074074073
# Iteration: 49
# Episode Reward: 0.24074074074074073
# Average Reward Across Episodes: 0.6267589418057387
# Lang Goal: pack all the purple and red blocks into the brown box
# Single timestep reward: 0.5714285714285714
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.19047619047619047
# Single timestep reward: 0.0
# Single timestep reward: -0.19047619047619047
# Single timestep reward: 0.2857142857142857
# Single timestep reward: 0.0
# Single timestep reward: 0.1428571428571429
# Iteration: 50
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.6340773939271949
# Lang Goal: pack all the purple and red blocks into the brown box
# Single timestep reward: 0.06741573033707865
# Single timestep reward: 0.18726591760299627
# Single timestep reward: 0.16104868913857678
# Single timestep reward: 0.10486891385767794
# Single timestep reward: 0.11610486891385763
# Single timestep reward: -0.022471910112359605
# Single timestep reward: 0.07116104868913864
# Single timestep reward: 0.014981273408239737
# Single timestep reward: 0.011235955056179692
# Single timestep reward: 0.101123595505618
# Iteration: 51
# Episode Reward: 0.8127340823970037
# Average Reward Across Episodes: 0.6375130994746914
# Lang Goal: pack all the blue and brown blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.12719298245614036
# Single timestep reward: 0.21052631578947367
# Single timestep reward: 0.15789473684210525
# Single timestep reward: 0.004385964912280715
# Single timestep reward: 0.00877192982456143
# Single timestep reward: 0.0
# Single timestep reward: 0.013157894736842035
# Single timestep reward: 0.01754385964912286
# Iteration: 52
# Episode Reward: 0.5394736842105263
# Average Reward Across Episodes: 0.6356632991866882
# Lang Goal: pack all the orange and yellow blocks into the brown box
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.07142857142857145
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.031746031746031744
# Single timestep reward: 0.3095238095238095
# Single timestep reward: 0.015873015873015928
# Single timestep reward: 0.12698412698412698
# Single timestep reward: -0.12698412698412698
# Iteration: 53
# Episode Reward: 0.7142857142857143
# Average Reward Across Episodes: 0.6371192698366703
# Lang Goal: pack all the blue blocks into the brown box
# Single timestep reward: 0.32
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.32
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 54
# Episode Reward: 0.0
# Average Reward Across Episodes: 0.6255352831123672
# Lang Goal: pack all the white and brown blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.002136752136752137
# Single timestep reward: 0.038461538461538464
# Single timestep reward: 0.0
# Single timestep reward: -0.002136752136752136
# Single timestep reward: 0.07692307692307693
# Single timestep reward: 0.008547008547008544
# Single timestep reward: 0.07692307692307693
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 55
# Episode Reward: 0.20085470085470086
# Average Reward Across Episodes: 0.6179517012863377
# Lang Goal: pack all the red and purple blocks into the brown box
# Single timestep reward: 0.05844155844155844
# Single timestep reward: 0.05844155844155844
# Single timestep reward: 0.04761904761904763
# Single timestep reward: 0.05844155844155843
# Single timestep reward: 0.07792207792207795
# Single timestep reward: 0.09740259740259738
# Single timestep reward: 0.12987012987012986
# Single timestep reward: 0.09740259740259738
# Single timestep reward: 0.04761904761904767
# Single timestep reward: 0.03246753246753242
# Iteration: 56
# Episode Reward: 0.7056277056277056
# Average Reward Across Episodes: 0.6194898768010986
# Lang Goal: pack all the green blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.32
# Iteration: 57
# Episode Reward: 0.32
# Average Reward Across Episodes: 0.6143262582355624
# Lang Goal: pack all the cyan and purple blocks into the brown box
# Single timestep reward: 0.35714285714285715
# Single timestep reward: 0.5714285714285714
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 58
# Episode Reward: 0.9285714285714286
# Average Reward Across Episodes: 0.6196524475632889
# Lang Goal: pack all the blue and gray blocks into the brown box
# Single timestep reward: 0.16666666666666666
# Single timestep reward: 0.08796296296296299
# Single timestep reward: 0.15277777777777773
# Single timestep reward: 0.013888888888888895
# Single timestep reward: 0.06481481481481483
# Single timestep reward: 0.041666666666666685
# Single timestep reward: 0.07870370370370372
# Single timestep reward: 0.13888888888888884
# Single timestep reward: 0.02314814814814814
# Single timestep reward: 0.0
# Iteration: 59
# Episode Reward: 0.7685185185185185
# Average Reward Across Episodes: 0.6221335487458758
# Lang Goal: pack all the green and yellow blocks into the brown box
# Single timestep reward: 0.4
# Single timestep reward: 0.4555555555555555
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.04444444444444451
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 60
# Episode Reward: 0.9
# Average Reward Across Episodes: 0.6266887364713533
# Lang Goal: pack all the green and blue blocks into the brown box
# Single timestep reward: 0.022222222222222223
# Single timestep reward: 0.21666666666666667
# Single timestep reward: 0.0111111111111111
# Single timestep reward: 0.3111111111111111
# Single timestep reward: -0.005555555555555536
# Single timestep reward: 0.0
# Single timestep reward: 0.19999999999999996
# Single timestep reward: -0.19999999999999996
# Single timestep reward: 0.005555555555555536
# Single timestep reward: 0.0
# Iteration: 61
# Episode Reward: 0.5611111111111111
# Average Reward Across Episodes: 0.6256310328365108
# Lang Goal: pack all the purple and gray blocks into the brown box
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.09090909090909091
# Single timestep reward: 0.0
# Single timestep reward: 0.04713804713804712
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.06060606060606061
# Single timestep reward: 0.09090909090909094
# Single timestep reward: 0.09090909090909094
# Single timestep reward: -0.047138047138047146
# Single timestep reward: 0.07407407407407407
# Iteration: 62
# Episode Reward: 0.6498316498316499
# Average Reward Across Episodes: 0.6260151696142117
# Lang Goal: pack all the cyan and blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.20202020202020202
# Single timestep reward: 0.0
# Single timestep reward: 0.2424242424242424
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.202020202020202
# Iteration: 63
# Episode Reward: 0.24242424242424243
# Average Reward Across Episodes: 0.6200215613768684
# Lang Goal: pack all the purple and brown blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.1925925925925926
# Single timestep reward: 0.0
# Single timestep reward: 0.014814814814814808
# Single timestep reward: 0.007407407407407418
# Single timestep reward: -0.037037037037037035
# Single timestep reward: -0.17777777777777778
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.13333333333333333
# Iteration: 64
# Episode Reward: 0.13333333333333333
# Average Reward Across Episodes: 0.6125340501761984
# Lang Goal: pack all the gray and cyan blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.3125
# Single timestep reward: 0.125
# Single timestep reward: 0.1527777777777778
# Single timestep reward: 0.125
# Single timestep reward: 0.01388888888888884
# Single timestep reward: 0.01388888888888895
# Single timestep reward: -0.1597222222222222
# Single timestep reward: 0.13888888888888884
# Single timestep reward: -0.11111111111111105
# Iteration: 65
# Episode Reward: 0.6111111111111112
# Average Reward Across Episodes: 0.612512490493394
# Lang Goal: pack all the blue and white blocks into the brown box
# Single timestep reward: 0.14423076923076922
# Single timestep reward: 0.11538461538461542
# Single timestep reward: 0.10256410256410253
# Single timestep reward: 0.0
# Single timestep reward: 0.11538461538461542
# Single timestep reward: -0.0352564102564103
# Single timestep reward: 0.0
# Single timestep reward: 0.028846153846153855
# Single timestep reward: 0.08974358974358976
# Single timestep reward: 0.012820512820512775
# Iteration: 66
# Episode Reward: 0.5737179487179487
# Average Reward Across Episodes: 0.6119334674818201
# Lang Goal: pack all the cyan and brown blocks into the brown box
# Single timestep reward: 0.5
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.2222222222222222
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 67
# Episode Reward: 0.7222222222222222
# Average Reward Across Episodes: 0.6135553609338847
# Lang Goal: pack all the brown and yellow blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.033333333333333326
# Single timestep reward: 0.2555555555555556
# Single timestep reward: 0.011111111111111072
# Single timestep reward: -0.26666666666666666
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 68
# Episode Reward: 0.7
# Average Reward Across Episodes: 0.6148081817899155
# Lang Goal: pack all the purple blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: -0.3333333333333333
# Single timestep reward: 0.4166666666666667
# Warning: movej exceeded 5 second timeout. Skipping.
# Single timestep reward: 0.0
# Iteration: 69
# Episode Reward: 0.4166666666666667
# Average Reward Across Episodes: 0.6119775887167261
# Lang Goal: pack all the yellow and cyan blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.05921052631578947
# Single timestep reward: 0.0
# Single timestep reward: 0.12280701754385967
# Single timestep reward: 0.03728070175438594
# Single timestep reward: 0.10526315789473686
# Single timestep reward: 0.09868421052631576
# Single timestep reward: 0.04385964912280704
# Single timestep reward: 0.059210526315789436
# Single timestep reward: 0.0
# Iteration: 70
# Episode Reward: 0.5263157894736842
# Average Reward Across Episodes: 0.6107710845020354
# Lang Goal: pack all the green and red blocks into the brown box
# Single timestep reward: 0.14102564102564102
# Single timestep reward: 0.0
# Single timestep reward: 0.26282051282051283
# Single timestep reward: -0.006410256410256443
# Single timestep reward: 0.01282051282051283
# Single timestep reward: 0.0
# Single timestep reward: 0.01282051282051283
# Single timestep reward: 0.0
# Single timestep reward: 0.0064102564102563875
# Single timestep reward: 0.0
# Iteration: 71
# Episode Reward: 0.42948717948717946
# Average Reward Across Episodes: 0.6082532524879402
# Lang Goal: pack all the pink and green blocks into the brown box
# Single timestep reward: 0.07272727272727272
# Single timestep reward: 0.054545454545454536
# Single timestep reward: 0.0
# Single timestep reward: 0.07272727272727275
# Single timestep reward: 0.048484848484848464
# Single timestep reward: 0.054545454545454564
# Single timestep reward: 0.0727272727272727
# Single timestep reward: 0.07272727272727275
# Single timestep reward: 0.054545454545454564
# Single timestep reward: 0.03838383838383841
# Iteration: 72
# Episode Reward: 0.5414141414141415
# Average Reward Across Episodes: 0.6073376482266551
# Lang Goal: pack all the yellow and cyan blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.06782945736434108
# Single timestep reward: 0.11627906976744186
# Single timestep reward: 0.0736434108527132
# Single timestep reward: 0.03294573643410853
# Single timestep reward: 0.08720930232558138
# Single timestep reward: 0.06976744186046513
# Single timestep reward: 0.0
# Single timestep reward: 0.03294573643410853
# Iteration: 73
# Episode Reward: 0.4806201550387597
# Average Reward Across Episodes: 0.6056252496700619
# Lang Goal: pack all the blue and purple blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.11111111111111116
# Single timestep reward: -0.11111111111111116
# Single timestep reward: 0.0
# Iteration: 74
# Episode Reward: 0.6666666666666666
# Average Reward Across Episodes: 0.6064391352300167
# Lang Goal: pack all the blue and white blocks into the brown box
# Single timestep reward: 0.2
# Single timestep reward: 0.0733333333333333
# Single timestep reward: 0.09333333333333332
# Single timestep reward: 0.09333333333333338
# Single timestep reward: 0.06
# Single timestep reward: 0.016666666666666607
# Single timestep reward: 0.0
# Single timestep reward: 0.06666666666666676
# Single timestep reward: -0.14666666666666672
# Single timestep reward: 0.06666666666666665
# Iteration: 75
# Episode Reward: 0.5233333333333333
# Average Reward Across Episodes: 0.6053456378366393
# Lang Goal: pack all the brown and gray blocks into the brown box
# Single timestep reward: 0.07894736842105263
# Single timestep reward: 0.0
# Single timestep reward: 0.10526315789473684
# Single timestep reward: 0.10526315789473686
# Single timestep reward: 0.10526315789473684
# Single timestep reward: 0.09064327485380114
# Single timestep reward: 0.026315789473684237
# Single timestep reward: 0.0029239766081871066
# Single timestep reward: 0.026315789473684292
# Single timestep reward: 0.0
# Iteration: 76
# Episode Reward: 0.5409356725146199
# Average Reward Across Episodes: 0.6045091447805094
# Lang Goal: pack all the blue and brown blocks into the brown box
# Single timestep reward: 0.140625
# Single timestep reward: 0.0
# Single timestep reward: 0.3125
# Single timestep reward: 0.0
# Single timestep reward: 0.15625
# Single timestep reward: 0.0
# Single timestep reward: -0.03125
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.015625
# Iteration: 77
# Episode Reward: 0.59375
# Average Reward Across Episodes: 0.6043712070269132
# Lang Goal: pack all the gray and purple blocks into the brown box
# Single timestep reward: 0.26785714285714285
# Single timestep reward: 0.2142857142857143
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.1964285714285714
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.04761904761904756
# Single timestep reward: -0.23809523809523814
# Iteration: 78
# Episode Reward: 0.5357142857142857
# Average Reward Across Episodes: 0.6035021320735887
# Lang Goal: pack all the gray and green blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.3055555555555555
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.02777777777777768
# Iteration: 79
# Episode Reward: 0.6111111111111112
# Average Reward Across Episodes: 0.6035972443115578
# Lang Goal: pack all the white and brown blocks into the brown box
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.19999999999999996
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.01481481481481478
# Iteration: 80
# Episode Reward: 0.48148148148148145
# Average Reward Across Episodes: 0.6020896423013099
# Lang Goal: pack all the pink blocks into the brown box
# Single timestep reward: 1.0
# Iteration: 81
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.6069422076390989
# Lang Goal: pack all the blue and yellow blocks into the brown box
# Single timestep reward: 0.3
# Single timestep reward: 0.2
# Single timestep reward: 0.16666666666666663
# Single timestep reward: 0.025000000000000022
# Single timestep reward: 0.0
# Single timestep reward: 0.008333333333333304
# Single timestep reward: 0.0
# Single timestep reward: 0.07500000000000007
# Single timestep reward: 0.008333333333333304
# Single timestep reward: 0.0
# Iteration: 82
# Episode Reward: 0.7833333333333333
# Average Reward Across Episodes: 0.6090674019245715
# Lang Goal: pack all the gray and orange blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.23076923076923078
# Single timestep reward: 0.10256410256410253
# Single timestep reward: -0.10256410256410253
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 83
# Episode Reward: 0.23076923076923078
# Average Reward Across Episodes: 0.6045638522679604
# Lang Goal: pack all the blue and orange blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.3037037037037037
# Single timestep reward: 0.029629629629629617
# Single timestep reward: -0.029629629629629617
# Single timestep reward: 0.0
# Single timestep reward: 0.2962962962962963
# Single timestep reward: 0.10370370370370374
# Single timestep reward: -0.10370370370370374
# Single timestep reward: 0.28888888888888886
# Single timestep reward: -0.17037037037037028
# Iteration: 84
# Episode Reward: 0.7185185185185186
# Average Reward Across Episodes: 0.6059044954003199
# Lang Goal: pack all the red and green blocks into the brown box
# Single timestep reward: 0.13333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.14285714285714288
# Single timestep reward: 0.06666666666666665
# Single timestep reward: -0.1523809523809524
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: -0.057142857142857134
# Single timestep reward: -0.13333333333333333
# Iteration: 85
# Episode Reward: 0.0
# Average Reward Across Episodes: 0.5988590942910139
# Lang Goal: pack all the blue and brown blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.027777777777777776
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.08333333333333333
# Iteration: 86
# Episode Reward: 0.1111111111111111
# Average Reward Across Episodes: 0.5932527956337738
# Lang Goal: pack all the yellow and gray blocks into the brown box
# Single timestep reward: 0.2328042328042328
# Single timestep reward: 0.19576719576719576
# Single timestep reward: -0.010582010582010581
# Single timestep reward: 0.19047619047619052
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.10582010582010581
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 87
# Episode Reward: 0.7142857142857143
# Average Reward Across Episodes: 0.5946281697093639
# Lang Goal: pack all the red and purple blocks into the brown box
# Single timestep reward: 0.25
# Single timestep reward: 0.125
# Single timestep reward: 0.3472222222222222
# Single timestep reward: 0.02777777777777779
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.11805555555555558
# Single timestep reward: -0.11805555555555558
# Iteration: 88
# Episode Reward: 0.75
# Average Reward Across Episodes: 0.596373920611506
# Lang Goal: pack all the blue and cyan blocks into the brown box
# Single timestep reward: 0.28104575163398693
# Single timestep reward: 0.16993464052287582
# Single timestep reward: 0.1764705882352941
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 89
# Episode Reward: 0.6274509803921569
# Average Reward Across Episodes: 0.5967192212757355
# Lang Goal: pack all the red and cyan blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0582010582010582
# Single timestep reward: 0.19047619047619047
# Single timestep reward: 0.14285714285714285
# Single timestep reward: 0.11111111111111116
# Single timestep reward: 0.005291005291005235
# Single timestep reward: 0.20105820105820105
# Single timestep reward: 0.06349206349206349
# Single timestep reward: -0.08994708994708989
# Single timestep reward: 0.021164021164021163
# Iteration: 90
# Episode Reward: 0.7037037037037037
# Average Reward Across Episodes: 0.5978948749287901
# Lang Goal: pack all the yellow and blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.1388888888888889
# Single timestep reward: 0.47222222222222227
# Single timestep reward: -0.11111111111111116
# Single timestep reward: 0.38888888888888884
# Single timestep reward: -0.02777777777777768
# Single timestep reward: 0.02777777777777768
# Single timestep reward: -0.38888888888888884
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 91
# Episode Reward: 0.5
# Average Reward Across Episodes: 0.5968308002013032
# Lang Goal: pack all the brown and red blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.36363636363636365
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 92
# Episode Reward: 0.36363636363636365
# Average Reward Across Episodes: 0.5943233331414651
# Lang Goal: pack all the white and gray blocks into the brown box
# Single timestep reward: 0.20952380952380953
# Single timestep reward: 0.34285714285714286
# Single timestep reward: -0.09523809523809529
# Single timestep reward: -0.08571428571428569
# Single timestep reward: 0.48571428571428565
# Single timestep reward: 0.1428571428571429
# Iteration: 93
# Episode Reward: 1.0
# Average Reward Across Episodes: 0.5986390423633645
# Lang Goal: pack all the purple and red blocks into the brown box
# Single timestep reward: 0.06923076923076923
# Single timestep reward: 0.06923076923076923
# Single timestep reward: 0.08461538461538462
# Single timestep reward: 0.051282051282051294
# Single timestep reward: 0.11538461538461536
# Single timestep reward: 0.0
# Single timestep reward: 0.0641025641025641
# Single timestep reward: 0.06923076923076926
# Single timestep reward: 0.017948717948717885
# Single timestep reward: -0.012820512820512775
# Iteration: 94
# Episode Reward: 0.5282051282051282
# Average Reward Across Episodes: 0.5978976327406462
# Lang Goal: pack all the cyan and blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.2727272727272727
# Single timestep reward: 0.19191919191919193
# Single timestep reward: 0.08080808080808077
# Single timestep reward: 0.0
# Single timestep reward: 0.26262626262626265
# Single timestep reward: -0.06060606060606055
# Single timestep reward: -0.2020202020202021
# Single timestep reward: 0.0
# Single timestep reward: 0.2222222222222222
# Iteration: 95
# Episode Reward: 0.7676767676767676
# Average Reward Across Episodes: 0.5996661653962309
# Lang Goal: pack all the orange and pink blocks into the brown box
# Single timestep reward: 0.04938271604938271
# Single timestep reward: 0.002469135802469137
# Single timestep reward: 0.06666666666666668
# Single timestep reward: 0.10864197530864197
# Single timestep reward: 0.034567901234567905
# Single timestep reward: 0.12839506172839504
# Single timestep reward: 0.0
# Single timestep reward: 0.108641975308642
# Single timestep reward: 0.0
# Single timestep reward: 0.09629629629629632
# Iteration: 96
# Episode Reward: 0.5950617283950618
# Average Reward Across Episodes: 0.5996186969735384
# Lang Goal: pack all the gray blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.3333333333333333
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 97
# Episode Reward: 0.3333333333333333
# Average Reward Across Episodes: 0.5969014993853731
# Lang Goal: pack all the orange and blue blocks into the brown box
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.25757575757575757
# Single timestep reward: 0.12121212121212122
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Single timestep reward: 0.0
# Iteration: 98
# Episode Reward: 0.3787878787878788
# Average Reward Across Episodes: 0.59469833150055
# Lang Goal: pack all the orange and pink blocks into the brown box
# Single timestep reward: 0.0736196319018405
# Single timestep reward: 0.0736196319018405
# Single timestep reward: 0.09202453987730061
# Single timestep reward: 0.08588957055214724
# Single timestep reward: 0.07566462167689159
# Single timestep reward: 0.05521472392638038
# Single timestep reward: 0.0
# Single timestep reward: 0.06748466257668717
# Single timestep reward: 0.04907975460122693
# Single timestep reward: 0.04089979550102252
# Iteration: 99
# Episode Reward: 0.6134969325153374
# Average Reward Across Episodes: 0.5948863175106979
